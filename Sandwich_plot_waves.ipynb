# %%
# Sandwich Waves
import pandas as pd
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import datetime

# %%
buoy = "44090"
# Open dataset
url ='https://dods.ndbc.noaa.gov/thredds/dodsC/data/stdmet/' + str(buoy) + '/' + str(buoy) + 'h9999.nc'
ds = xr.open_dataset(url)
ds
# Out:
# <xarray.Dataset>
# Dimensions:                  (latitude: 1, longitude: 1, time: 2294)
# Coordinates:
#   * latitude                 (latitude) float32 41.84
#   * longitude                (longitude) float32 -70.33
#   * time                     (time) datetime64[ns] 2023-10-13T17:30:00 ... 20...
# Data variables: (12/13)
#     air_pressure             (time, latitude, longitude) float32 ...
#     air_temperature          (time, latitude, longitude) float32 ...
#     average_wpd              (time, latitude, longitude) timedelta64[ns] ...
#     dewpt_temperature        (time, latitude, longitude) float32 ...
#     dominant_wpd             (time, latitude, longitude) timedelta64[ns] ...
#     gust                     (time, latitude, longitude) float32 ...
#     ...                       ...
#     sea_surface_temperature  (time, latitude, longitude) float32 ...
#     visibility               (time, latitude, longitude) float32 ...
# ...

# %%
lat1 = ds.latitude.values
lon1 = ds.longitude.values
print(lon1,lat1)
#ds = ds.sel(time=slice("2020-01-01","2023-06-01")) ####<<<<<We can us the datetime object to subset. no need to convert to strings. 

plt.figure()
ds.wave_height.plot()
plt.title('NDBC buoy observations')
plt.ylabel('Significant Wave height (m)')
plt.xlabel('YYYY-MM-DD, UTC')
fig_name = 'NDBC'+buoy + '_Hs.png'
#plt.savefig(fig_name)
# Out:
# [-70.329] [41.84]

# %%
urla ='https://dods.ndbc.noaa.gov/thredds/dodsC/data/stdmet/' + str(buoy) + '/' + str(buoy) + '.ncml'
dsa = xr.open_dataset(urla)
dsa
# Out:
# <xarray.Dataset>
# Dimensions:                  (latitude: 1, longitude: 1, time: 121769)
# Coordinates:
#   * latitude                 (latitude) float32 41.84
#   * longitude                (longitude) float32 -70.33
#   * time                     (time) datetime64[ns] 2016-05-23T15:34:00 ... 20...
# Data variables: (12/13)
#     wind_dir                 (time, latitude, longitude) float64 ...
#     wind_spd                 (time, latitude, longitude) float32 ...
#     gust                     (time, latitude, longitude) float32 ...
#     wave_height              (time, latitude, longitude) float32 ...
#     dominant_wpd             (time, latitude, longitude) timedelta64[ns] ...
#     average_wpd              (time, latitude, longitude) timedelta64[ns] ...
#     ...                       ...
#     air_pressure             (time, latitude, longitude) float32 ...
#     air_temperature          (time, latitude, longitude) float32 ...
# ...

# %%
plt.figure()
dsa.wave_height.plot()
plt.title('NDBC buoy observations')
plt.ylabel('Significant Wave Height (m)')
plt.xlabel('YYYY-MM-DD, UTC')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [12], in <cell line: 2>()
#       1 plt.figure()
# ----> 2 dsa.wave_height.plot()
#       3 plt.title('NDBC buoy observations')
#       4 plt.ylabel('Significant Wave height (m)')
#
# File ~\Anaconda3\envs\CRS\lib\site-packages\xarray\plot\accessor.py:47, in DataArrayPlotAccessor.__call__(self, **kwargs)
#      45 @functools.wraps(dataarray_plot.plot, assigned=("__doc__", "__annotations__"))
#      46 def __call__(self, **kwargs) -> Any:
# ---> 47     return dataarray_plot.plot(self._da, **kwargs)
#
# File ~\Anaconda3\envs\CRS\lib\site-packages\xarray\plot\dataarray_plot.py:267, in plot(darray, row, col, col_wrap, ax, hue, subplot_kws, **kwargs)
#     218 def plot(
#     219     darray: DataArray,
#     220     *,
#    (...)
#     227     **kwargs: Any,
#     228 ) -> Any:
#     229     """
# ...
